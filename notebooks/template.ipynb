# %% [markdown]
# # Notebook Title
#
# Description of what this notebook does.

# %% [markdown]
# ## Setup
#
# Run this cell first to set up the environment.

# %%
# Setup - works in both Colab and local environments
import sys
import os

# Detect environment
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # Clone repo and install dependencies in Colab
    # !git clone https://github.com/m0xt64/colab-notebooks.git /content/repo 2>/dev/null || true
    # %cd /content/repo
    # !pip install -q -r requirements.txt
    sys.path.insert(0, '/content/repo')
else:
    # Local: add project root to path
    project_root = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
    if project_root not in sys.path:
        sys.path.insert(0, project_root)
    os.chdir(project_root)

# Import shared utilities
from src import get_secret

print(f"Running in: {'Google Colab' if IN_COLAB else 'Local environment'}")

# %% [markdown]
# ## Get API Keys
#
# Use `get_secret('KEY_NAME')` to retrieve any API key from Colab Secrets or your local `.env` file.

# %%
# Example: get your Dune API key
dune_key = get_secret('DUNE_API_KEY')

# Other keys you might use:
# openai_key = get_secret('OPENAI_API_KEY')
# anthropic_key = get_secret('ANTHROPIC_API_KEY')

# %% [markdown]
# ## Your Code Here

# %%
# Start coding!
