# %% [markdown]
# # Notebook Title
#
# Description of what this notebook does.

# %% [markdown]
# ## Setup
#
# Run this cell first to set up the environment.

# %%
# Setup - works in both Colab and local environments
import sys
import os

# Detect environment
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # Clone repo and install dependencies in Colab
    # !git clone https://github.com/m0xt64/colab-notebooks.git /content/repo 2>/dev/null || true
    # %cd /content/repo
    # !pip install -q -r requirements.txt
    sys.path.insert(0, '/content/repo')
else:
    # Local: add project root to path
    project_root = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
    if project_root not in sys.path:
        sys.path.insert(0, project_root)
    os.chdir(project_root)

# Import shared utilities
from src import get_secret, get_openai_client, get_anthropic_client

print(f"Running in: {'Google Colab' if IN_COLAB else 'Local environment'}")

# %% [markdown]
# ## Initialize API Clients
#
# Make sure you've added your API keys to Colab Secrets (key icon in left sidebar):
# - `OPENAI_API_KEY`
# - `ANTHROPIC_API_KEY`

# %%
# Initialize clients (uncomment the ones you need)

# OpenAI
# openai_client = get_openai_client()

# Anthropic
# anthropic_client = get_anthropic_client()

# Custom API key
# my_api_key = get_secret('MY_CUSTOM_API_KEY')

# %% [markdown]
# ## Your Code Here

# %%
# Start coding!
